# %% [markdown]
# <a href="https://colab.research.google.com/github/pranalinarkhede/machine_learning/blob/main/EDA_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('/content/train-200907-141856.csv')

# %%
sns.countplot(x='Survived',data=df)

# %%
sns.countplot(x='Survived',data=df,hue='Sex')

# %%
sns.lineplot(x='Age',y='Fare',data=df)

# %%
df.plot.scatter(x='Age',y='Fare')

# %%
df.plot.scatter(x='Age',y='Survived')

# %%
df.plot.scatter('Age','Fare')

# %%
df['Age'].hist(bins=80)

# %%
sizes=df['Survived'].value_counts()
fig1,ax1 = plt.subplots()
ax1.pie(sizes,labels=['Not Survived','Survived'],autopct='%1.1f%%',shadow=True)
plt.show()
